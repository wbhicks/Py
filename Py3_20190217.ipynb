# %%
print("hello" + " world")
# Out:
# hello world

# %% [markdown]
# This is a text cell.

# %%
a = 1 + 2
a
# Out:
# 3

# %%
ls /bin | grep less
# Out:
# bzless@
# less*
# lessecho*
# lessfile@
# lesskey*
# lesspipe*
# zless*

# %%
# !pip install --upgrade -q gspread

# %% [markdown]
# (no output from above code cell)

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(GoogleCredentials.get_application_default())

# %% [markdown]
# (handled smoothly!)

# %%
sh = gc.create('spreadsheet-for-Py3_201902127')

# %% [markdown]
# There it is (in top-level Drive folder BTW)

# %%
# Open our new sheet and add some data.
worksheet = gc.open('spreadsheet-for-Py3_201902127').sheet1

cell_list = worksheet.range('A1:D5')

import random
for cell in cell_list:
  cell.value = random.randint(1, 1000)

worksheet.update_cells(cell_list)
# Out:
# {'spreadsheetId': '1dHs5q6pLRRMSHR1343s50TItyTeaBNHXUv1R8NlSTKM',
#  'updatedCells': 20,
#  'updatedColumns': 4,
#  'updatedRange': 'Sheet1!A1:D5',
#  'updatedRows': 5}

# %% [markdown]
# works

# %%
# Open our new sheet and read some data.
worksheet = gc.open('spreadsheet-for-Py3_201902127').sheet1

# get_all_values gives a list of rows.
rows = worksheet.get_all_values()
print(rows)

# Convert to a DataFrame and render.
import pandas as pd
pd.DataFrame.from_records(rows)
# Out:
# [['274', '709', '30', '53'], ['485', '580', '306', '965'], ['612', '466', '750', '544'], ['653', '722', '95', '428'], ['710', '482', '765', '642']]
#      0    1    2    3
# 0  274  709   30   53
# 1  485  580  306  965
# 2  612  466  750  544
# 3  653  722   95  428
# 4  710  482  765  642
