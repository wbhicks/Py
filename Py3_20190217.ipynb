# %%
print("hello" + " world")
# Out:
# hello world

# %% [markdown]
# This is a text cell.

# %%
a = 1 + 2
a
# Out:
# 3

# %%
ls /bin | grep less
# Out:
# bzless@
# less*
# lessecho*
# lessfile@
# lesskey*
# lesspipe*
# zless*
